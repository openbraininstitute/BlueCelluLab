# %% [markdown]
# # Simulating a single cell
#
# This notebook shows how to simulate a single cell using the `Cell` class.

# %% [markdown]
# ## Compiling mechanisms

# %% [markdown]
# Before loading the cell, the cell mechanisms need to be compiled and provided. This compilation step is a performance requirement.
#
# Refer to the [MOD2IR: High-Performance Code Generation for a Biophysically Detailed Neuronal Simulation DSL](https://dl.acm.org/doi/abs/10.1145/3578360.3580268) publication to learn more about the compilation process.
#
#
# If the mechanisms are not compiled, you need to run the `nrnivmodl` command to perform the compilation.
#
# The mechanisms are already available in the examples directory.
#
# With NEURON installed, simply run the following command for the compilation.

# %% [markdown]
# **Note**: The compiled mechanisms must be loaded before importing Bluecellulab. If not, NEURON may crash or behave unexpectedly.

# %%
# !nrnivmodl ../mechanisms

# %%
from pathlib import Path

from matplotlib import pyplot as plt
from matplotlib.pyplot import get_cmap

import seaborn as sns

sns.set_style("whitegrid")

from bluecellulab import Cell, Simulation
from bluecellulab.circuit.circuit_access import EmodelProperties

from bluecellulab.stimulus.circuit_stimulus_definitions import OrnsteinUhlenbeck, ShotNoise
from bluecellulab import RNGSettings
from bluecellulab import tools

# %% [markdown]
# ## Loading the cell
#
# A Cell is consisting of the two following components
#
# - Electrophysiology - represented as hoc
# - Morphology (shape) - represented as asc in this tutorial

# %%
hoc_file = Path("hoc") / "cADpyr_L2TPC.hoc"
morph_file = Path("morphology") / "rr110330_C3_idA.asc"

# %% [markdown]
# This command will compile the mechanisms files. The compilation step

# %%
morph_file
# Out:
# PosixPath('morphology/rr110330_C3_idA.asc')

# %%
emodel_properties = EmodelProperties(threshold_current=1.1433533430099487,
                                     holding_current=1.4146618843078613,
                                     AIS_scaler=1.4561502933502197)
cell = Cell(hoc_file, morph_file, template_format="v6", emodel_properties=emodel_properties)

# %%
cell
# Out:
# Cell Object: <bluecellulab.cell.core.Cell object at 0x17f0775c0>.
# NEURON ID: cADpyr_L2TPC_bluecellulab_c24cfe77cb1548bd8b98cb058c143c9a.

# %% [markdown]
# ### Exploring cell's attributes
#
# Morphology related attributes such as the Radius (Ra) of a section can be accessed as follows:

# %%
cell.soma.Ra
# Out:
# 100.0

# %% [markdown]
# To see the children of a section, you can use the `children` attribute.

# %%
cell.soma.children()
# Out:
# [cADpyr_L2TPC_bluecellulab_c24cfe77cb1548bd8b98cb058c143c9a[0].apic[0],
#  cADpyr_L2TPC_bluecellulab_c24cfe77cb1548bd8b98cb058c143c9a[0].dend[0],
#  cADpyr_L2TPC_bluecellulab_c24cfe77cb1548bd8b98cb058c143c9a[0].axon[0]]

# %% [markdown]
# Properties of other sections such as length(L) can also be displayed as follows:

# %%
cell.apical[0].Ra
# Out:
# 100.0

# %%
cell.apical[0].L
# Out:
# 9.530376893488256

# %% [markdown]
# Electrophysiological attributes such as the holding and threshold currents of the cell can be accessed as follows:

# %%
cell.hypamp  # holding current
# Out:
# 1.4146618843078613

# %%
cell.threshold
# Out:
# 1.1433533430099487

# %% [markdown]
# ## Simulation
#
# In this step we will apply some stimulation to the cell and run a simulation.

# %% [markdown]
# Here we create a Simulation object and add the cell we wish to simulate to it.

# %%
sim = Simulation()
sim.add_cell(cell)

# %% [markdown]
# ### Adding a step current
#
# Here a step current is set to be given to the cell during the simulation.

# %%
cell.add_step(start_time=15.0, stop_time=25.0, level=1.0)
# Out:
# TStim[0]

# %% [markdown]
# To run the cell, we call the `run` method of the simulation object.

# %%
sim.run(45, cvode=False)

# %% [markdown]
# Retrieving the time and voltage values of the simulation is done as follows:

# %%
time, voltage = cell.get_time(), cell.get_soma_voltage()

# %% [markdown]
# **Note**: To retrieve the voltage we used `cell.get_soma_voltage()`. In the next steps we will see how to retrieve the voltage from other sections.

# %%
plt.plot(time, voltage)
plt.xlabel("Time (ms)")
plt.ylabel("Voltage (mV)")
# Out:
# Text(0, 0.5, 'Voltage (mV)')

# %% [markdown]
# Here at the beginning we see a single spike and then we can clearly observe the impact of the step current we injected between 15 and 25 ms.

# %% [markdown]
# ### Adding a more complex stimulation
#
# Besides the step current, we can also add more complex stimulation to the cell.
# In this example we will add a Poisson shot noise current to the cell.

# %% [markdown]
# Here we create a new Cell instance since the underlying NEURON implementation leaves some state after adding stimulus to the cell.
#
# We do not want the previously injected step current to interfere with the new stimulus.

# %%
cell = Cell(hoc_file, morph_file, template_format="v6", emodel_properties=emodel_properties)
sim = Simulation()
sim.add_cell(cell)

# %% [markdown]
# Here to define the ShotNoise stimulus, we need to create an object of type ShotNoise. The attributes of the stimulus object (ShotNoise object) are checked via a dynamic type checker to early detect errors and misuses.

# %%
shotnoise_stimulus = ShotNoise(
    target="single-cell", delay=15, duration=20,
    rise_time=0.4, decay_time=4, rate=2E3, amp_mean=40E-3, amp_var=16E-4,
    seed=3899663
)

# %% [markdown]
# Since ShotNoise is a stochastic signal, we need to set the rng_settings attribute of the cell.

# %%
rng_obj = RNGSettings.get_instance().set_seeds(base_seed=42)

# %% [markdown]
# Here we add the shotnoise to the middle point (denoted by 0.5) of soma

# %%
time_vec, stim_vec = cell.add_replay_shotnoise(
    cell.soma, 0.5,
    shotnoise_stimulus,
    shotnoise_stim_count=3)
time_vec = time_vec.to_python()
stim_vec = stim_vec.to_python()

# %% [markdown]
# Here is the current we injected to the cell.

# %%
plt.plot(time_vec, stim_vec)
plt.xlabel("Time (ms)")
plt.ylabel("Current (nA)")
# Out:
# Text(0, 0.5, 'Current (nA)')

# %%
sim.cells
# Out:
# [Cell Object: <bluecellulab.cell.core.Cell object at 0x324138890>.
#  NEURON ID: cADpyr_L2TPC_bluecellulab_007095c44a7140058b2bd7e6073dfe1a.]

# %%
sim.cells[0] is cell
# Out:
# True

# %%
sim.run(45, cvode=False)
time, voltage = cell.get_time(), cell.get_soma_voltage()

# %% [markdown]
# The figure below shows how the cell responded to the shotnoise.
#
# As in the previous stimulus, there is a single spike at the beginning and the impact of shotnoise begins at 15 ms and lasts for 20ms.
#
# Compared to the previous voltage figure, here we can tell that the shotnoise has a different effect on the cell.

# %%
plt.plot(time, voltage)
plt.xlabel("Time (ms)")
plt.ylabel("Voltage (mV)")
# Out:
# Text(0, 0.5, 'Voltage (mV)')

# %% [markdown]
# ### Using the spike detector
#
# The spike detector can be used to detect the exact time of the spikes.

# %%
cell = Cell(hoc_file, morph_file, template_format="v6", emodel_properties=emodel_properties)
tstim = cell.add_ramp(start_time=10.0, stop_time=30.0, start_level=0.5, stop_level=4.0)
sim = Simulation()
sim.add_cell(cell)

# %% [markdown]
# Before running the simulation, we need to add the spike detector via `start_recording_spikes` to the cell and set the threshold voltage.
#
# Above the threshold is considered a spike.
#
# `get_recorded_spikes` returns the time of the spikes from the section "soma".

# %%
cell.start_recording_spikes(None, location="soma", threshold=-10)
sim.run(45, cvode=False)
spikes = cell.get_recorded_spikes(location="soma", threshold=-10)
time, voltage = cell.get_time(), cell.get_soma_voltage()

# %%
print(f"spike times: {spikes}")
# Out:
# spike times: [0.7250000000999994, 10.925000000099914, 14.775000000099695, 18.150000000099503, 21.87500000009929, 27.72500000009896]

# %% [markdown]
# The detected spikes are denoted as red dashed lines in the voltage plot.

# %%
plt.plot(time, voltage)
plt.xlabel("Time (ms)")
plt.ylabel("Voltage (mV)")
# add spikes to the plot as dashed lines
for spike in spikes:
    plt.axvline(spike, c="r", linestyle="--")

# %% [markdown]
# ### Recording from another section
#
# Besides soma, the voltage can be recorded from other sections as well.
# Here we record from the axon initial segment (ais) and plot the voltage from both soma and AIS.

# %%
cell = Cell(hoc_file, morph_file, template_format="v6", emodel_properties=emodel_properties)
cell.add_ramp(start_time=10.0, stop_time=30.0, start_level=0.5, stop_level=4.0)
sim = Simulation()
sim.add_cell(cell)
cell.add_ais_recording(dt=cell.record_dt)

# %%
sim.run(45, cvode=False)

# %%
time = cell.get_time()
soma_voltage = cell.get_soma_voltage()
ais_voltage = cell.get_ais_voltage()

# %% [markdown]
# The dotted line shows the recordings from the axon initial segment.

# %%
plt.plot(time, soma_voltage, label="soma")
plt.plot(time, ais_voltage, label="ais", linestyle="--")
plt.legend()
plt.xlabel("Time (ms)")
plt.ylabel("Voltage (mV)")
# Out:
# Text(0, 0.5, 'Voltage (mV)')

# %% [markdown]
# ### Recording from all sections
#
# In this step we will go one level beyond and record from every section of the neuron.
#
# This time we will add an Ornstein-Uhlenbeck process current to the cell.

# %%
cell = Cell(hoc_file, morph_file, template_format="v6", emodel_properties=emodel_properties)
stimulus = OrnsteinUhlenbeck(
            target="single-cell", delay=15, duration=20,
            tau=2.8, sigma=0.64, mean=0.729, mode="current_clamp", dt=0.25, seed=1
        )
rng_obj = RNGSettings.get_instance().set_seeds(base_seed=42)
sim = Simulation()
sim.add_cell(cell)

# %% [markdown]
# With `add_allsections_voltagerecordings` we enable recording from every section of the cell.

# %%
cell.add_allsections_voltagerecordings()

# %%
time_vec, stim_vec = cell.add_ornstein_uhlenbeck(cell.soma, 0.5, stimulus, stim_count=1)

# %% [markdown]
# The Ornstein-Uhlenbeck signal is plotted below.

# %%
plt.plot(time_vec, stim_vec)
plt.xlabel("Time (ms)")
plt.ylabel("Current (nA)")
# Out:
# Text(0, 0.5, 'Current (nA)')

# %%
sim.run(45, cvode=False)

# %% [markdown]
# To get the recorded voltage from all sections, we use `get_allsections_voltage`.

# %%
recordings = cell.get_allsections_voltagerecordings()
time = cell.get_time()

# %% [markdown]
# Here in order to display how the voltage changes in different sections, we plot the voltage of the soma and its subsections. We will record voltages at the center (or (0.5) location) of each section.
#
# We use the `subtree` method to get the subsections.

# %%
recordings
# Out:
# {'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].soma[0]': array([-65.        , -60.97827517, -57.80286608, ..., -86.73682021,
#         -86.73984968, -86.74287885]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[0]': array([-65.        , -62.40622012, -59.8769138 , ..., -86.70528874,
#         -86.70836571, -86.71144211]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[1]': array([-65.        , -64.7966702 , -64.39596325, ..., -86.63942062,
#         -86.6425901 , -86.64575869]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[2]': array([-65.        , -64.99940043, -64.96681525, ..., -86.60717363,
#         -86.61037683, -86.61357915]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[3]': array([-65.        , -65.00074187, -64.97178022, ..., -86.60544006,
#         -86.6086445 , -86.61184807]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[4]': array([-65.        , -64.86630225, -64.54886861, ..., -86.63391453,
#         -86.63709017, -86.64026491]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[5]': array([-65.        , -65.00819612, -64.99351195, ..., -86.60886796,
#         -86.61207223, -86.6152756 ]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[6]': array([-65.        , -65.00925724, -64.99802609, ..., -86.60786223,
#         -86.61106756, -86.61427199]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[7]': array([-65.        , -64.39513196, -63.45317985, ..., -86.61973257,
#         -86.62293938, -86.62614482]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[8]': array([-65.        , -64.98758785, -64.92049628, ..., -86.55166209,
#         -86.55495223, -86.55824057]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[9]': array([-65.        , -64.85046209, -64.52696683, ..., -86.54996753,
#         -86.55328252, -86.55659541]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[10]': array([-65.        , -65.01573287, -65.02740273, ..., -86.47192364,
#         -86.47520779, -86.47849061]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[11]': array([-65.        , -64.92225785, -64.7216394 , ..., -86.52351744,
#         -86.52687653, -86.5302332 ]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[12]': array([-65.        , -64.94966727, -64.7965184 , ..., -86.51401604,
#         -86.51739173, -86.52076486]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[13]': array([-65.        , -64.95543999, -64.81802866, ..., -86.50318106,
#         -86.50657679, -86.50996981]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[14]': array([-65.        , -65.01682722, -65.03315544, ..., -86.26023672,
#         -86.26400437, -86.2677656 ]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[15]': array([-65.        , -65.01682063, -65.03363206, ..., -86.07430775,
#         -86.07840664, -86.08249561]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[16]': array([-65.        , -65.01682952, -65.03364899, ..., -86.07994541,
#         -86.084034  , -86.08811277]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[17]': array([-65.        , -65.00448694, -64.98096415, ..., -86.43809358,
#         -86.44161838, -86.44513952]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[18]': array([-65.        , -65.01686033, -65.03344029, ..., -86.22375738,
#         -86.22754123, -86.23131943]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[19]': array([-65.        , -65.01682164, -65.03363315, ..., -86.09871342,
#         -86.10257084, -86.10642188]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[20]': array([-65.        , -65.01684216, -65.03367296, ..., -86.12241034,
#         -86.12625396, -86.13009136]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[21]': array([-65.        , -65.01681752, -65.03319288, ..., -86.10885107,
#         -86.11328167, -86.11770174]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[22]': array([-65.        , -65.0167833 , -65.03355527, ..., -85.78000533,
#         -85.78547141, -85.79091893]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[23]': array([-65.        , -65.01679831, -65.0335857 , ..., -85.80150796,
#         -85.80690448, -85.81228299]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[0]': array([-65.        , -61.39913825, -58.27782905, ..., -86.71318526,
#         -86.71625694, -86.71932822]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[1]': array([-65.        , -62.86320922, -60.43122775, ..., -86.48329567,
#         -86.48675528, -86.49021371]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[2]': array([-65.        , -63.84265014, -62.29146218, ..., -86.11521198,
#         -86.11931038, -86.12340643]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[3]': array([-65.        , -64.78929397, -64.34573287, ..., -85.61293912,
#         -85.61811057, -85.62327747]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[4]': array([-65.        , -65.01650005, -65.0312415 , ..., -84.93909661,
#         -84.94543978, -84.95177866]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[5]': array([-65.        , -65.01682767, -65.03288795, ..., -83.26823607,
#         -83.27898446, -83.28971279]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[6]': array([-65.        , -65.01678028, -65.0335511 , ..., -79.36361835,
#         -79.38418581, -79.40470208]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[7]': array([-65.        , -65.01683199, -65.0336515 , ..., -79.68138673,
#         -79.70114243, -79.72084951]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[8]': array([-65.        , -65.01672174, -65.03343485, ..., -79.09014144,
#         -79.11140664, -79.13261819]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[9]': array([-65.        , -65.01672446, -65.03344017, ..., -79.09836918,
#         -79.11961337, -79.140804  ]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[10]': array([-65.        , -64.98176611, -64.89973341, ..., -84.64348841,
#         -84.64925372, -84.65501463]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[11]': array([-65.        , -65.01700652, -65.03399179, ..., -79.96239061,
#         -79.9745545 , -79.98670287]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[12]': array([-65.        , -65.0169032 , -65.03379166, ..., -77.1255414 ,
#         -77.14221651, -77.15886583]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[13]': array([-65.        , -65.01687286, -65.03373226, ..., -76.81217739,
#         -76.8293605 , -76.84651657]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[14]': array([-65.        , -65.01683684, -65.0336641 , ..., -76.67871061,
#         -76.69610958, -76.71348098]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[15]': array([-65.        , -65.0168366 , -65.03366345, ..., -76.67359702,
#         -76.6910043 , -76.70838398]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[16]': array([-65.        , -65.01683432, -65.03365699, ..., -76.61245269,
#         -76.62996188, -76.64744318]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[17]': array([-65.        , -65.01687501, -65.03373855, ..., -77.10365004,
#         -77.12034859, -77.13702138]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[18]': array([-65.        , -65.01700199, -65.0339858 , ..., -80.32767572,
#         -80.3366141 , -80.34554506]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[19]': array([-65.        , -65.01689014, -65.03376484, ..., -77.84123647,
#         -77.85158362, -77.86192041]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[20]': array([-65.        , -65.01680575, -65.03359974, ..., -77.58084582,
#         -77.59144379, -77.60203024]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[21]': array([-65.        , -65.01685817, -65.03370155, ..., -77.65867026,
#         -77.66919973, -77.679718  ]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[22]': array([-65.        , -65.01680004, -65.03358965, ..., -77.53172894,
#         -77.54238857, -77.55303639]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[23]': array([-65.        , -65.01679996, -65.03358942, ..., -77.5281597 ,
#         -77.5388233 , -77.54947507]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[24]': array([-65.        , -65.01688936, -65.03376271, ..., -77.775125  ,
#         -77.78543086, -77.79572686]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[25]': array([-65.        , -65.01685858, -65.03370254, ..., -77.56960734,
#         -77.57998391, -77.59035066]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[26]': array([-65.        , -65.01680005, -65.03358969, ..., -77.45276354,
#         -77.46320696, -77.47364034]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[27]': array([-65.        , -65.01679997, -65.03358946, ..., -77.44950868,
#         -77.45995411, -77.47038948]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[28]': array([-65.        , -65.01685842, -65.03370199, ..., -77.51123878,
#         -77.5215815 , -77.53191485]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[29]': array([-65.        , -65.01680015, -65.03358994, ..., -77.35004487,
#         -77.36039771, -77.37074156]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[30]': array([-65.        , -65.01678299, -65.03355324, ..., -77.22299202,
#         -77.23330134, -77.24360235]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[31]': array([-65.        , -65.01669042, -65.03337139, ..., -77.07470094,
#         -77.08497249, -77.0952364 ]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[32]': array([-65.        , -65.01669022, -65.03337083, ..., -77.07263144,
#         -77.08290234, -77.09316562]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[33]': array([-65.        , -64.90918328, -64.69767187, ..., -85.20274289,
#         -85.20780824, -85.21287018]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[34]': array([-65.        , -65.00886275, -65.00140254, ..., -83.62577831,
#         -83.63280788, -83.63983134]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[35]': array([-65.        , -65.01700137, -65.03397942, ..., -80.06493835,
#         -80.07665099, -80.08834947]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[36]': array([-65.        , -65.0168138 , -65.03361558, ..., -77.29344236,
#         -77.30909234, -77.32471888]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[37]': array([-65.        , -65.01686253, -65.03371341, ..., -77.87794843,
#         -77.89271486, -77.90746014]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[38]': array([-65.        , -65.01698725, -65.0339584 , ..., -79.73480876,
#         -79.74694911, -79.75907464]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[39]': array([-65.        , -65.01682118, -65.03363075, ..., -77.48302574,
#         -77.49836399, -77.51367963]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[40]': array([-65.        , -65.0168067 , -65.03360161, ..., -77.32030111,
#         -77.33588857, -77.35145265]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[41]': array([-65.        , -65.00954294, -65.00408547, ..., -83.37679454,
#         -83.38372709, -83.390654  ]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[42]': array([-65.        , -65.01700181, -65.03398216, ..., -79.97068335,
#         -79.98100171, -79.99130982]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[43]': array([-65.        , -65.01684873, -65.03368529, ..., -77.75441978,
#         -77.76709804, -77.77976083]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[44]': array([-65.        , -65.01674934, -65.03348975, ..., -77.46217707,
#         -77.47518125, -77.48816897]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[45]': array([-65.        , -65.01675687, -65.03350444, ..., -77.47442006,
#         -77.48741065, -77.50038482]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[46]': array([-65.        , -65.0168487 , -65.03368519, ..., -77.69465451,
#         -77.70738202, -77.72009414]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[47]': array([-65.        , -65.01674899, -65.0334887 , ..., -77.36535156,
#         -77.37843291, -77.39149797]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[48]': array([-65.        , -65.01674872, -65.03348796, ..., -77.3621046 ,
#         -77.37518946, -77.38825801]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[49]': array([-65.        , -65.01699206, -65.0337887 , ..., -80.62399788,
#         -80.63372476, -80.64344193]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[50]': array([-65.        , -65.01688206, -65.03375209, ..., -78.21668835,
#         -78.22943916, -78.24217215]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[51]': array([-65.        , -65.01695487, -65.03389735, ..., -78.42855676,
#         -78.44039987, -78.45223002]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[52]': array([-65.        , -65.01682109, -65.03363042, ..., -77.38927296,
#         -77.40197936, -77.41467168]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[53]': array([-65.        , -65.01687252, -65.03373062, ..., -77.5292316 ,
#         -77.54182562, -77.55440571]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[54]': array([-65.        , -65.01682287, -65.03363547, ..., -77.37771326,
#         -77.39043305, -77.40313874]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[55]': array([-65.        , -65.01682276, -65.03363517, ..., -77.37307366,
#         -77.38579735, -77.39850693]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[56]': array([-65.        , -63.69638538, -61.91559229, ..., -86.44202301,
#         -86.44562363, -86.449222  ]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[57]': array([-65.        , -65.01578214, -65.02773837, ..., -85.88053451,
#         -85.88516025, -85.88978266]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[58]': array([-65.        , -64.59290286, -63.86794497, ..., -86.07594391,
#         -86.08027496, -86.08460105]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[59]': array([-65.        , -64.96895379, -64.86048326, ..., -85.59416037,
#         -85.59943692, -85.60470578]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[60]': array([-65.        , -65.01528345, -65.02544063, ..., -84.29475548,
#         -84.30254917, -84.3103292 ]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[61]': array([-65.        , -65.0169789 , -65.03388316, ..., -83.33713268,
#         -83.34675842, -83.35636607]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[62]': array([-65.        , -65.01695428, -65.03389541, ..., -83.24269205,
#         -83.25248522, -83.26225981]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[63]': array([-65.        , -65.01694457, -65.0338783 , ..., -83.22423852,
#         -83.23406418, -83.24387116]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[64]': array([-65.        , -65.01693471, -65.0338623 , ..., -83.21659929,
#         -83.22643829, -83.23625857]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[65]': array([-65.        , -65.01693392, -65.03386097, ..., -83.21599059,
#         -83.22583065, -83.235652  ]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[66]': array([-65.        , -65.0169602 , -65.03388357, ..., -81.97117031,
#         -81.9834966 , -81.99579875]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[67]': array([-65.        , -65.01680661, -65.03360239, ..., -79.69935348,
#         -79.71620524, -79.73302159]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[68]': array([-65.        , -65.01687137, -65.03372882, ..., -79.77454416,
#         -79.79115096, -79.80772425]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[69]': array([-65.        , -65.01680217, -65.03359229, ..., -79.12967835,
#         -79.14752981, -79.16534519]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[70]': array([-65.        , -65.01679464, -65.03357715, ..., -78.62070104,
#         -78.6394849 , -78.65823139]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[71]': array([-65.        , -65.01665396, -65.0332942 , ..., -77.56663649,
#         -77.587373  , -77.60806898]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[72]': array([-65.        , -65.01672419, -65.03344014, ..., -77.98131962,
#         -78.001294  , -78.02122905]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[73]': array([-65.        , -65.01643062, -65.03081717, ..., -85.05095995,
#         -85.05729511, -85.06361999]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[74]': array([-65.        , -65.00931414, -65.00261088, ..., -85.6509487 ,
#         -85.65617235, -85.66138551]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[75]': array([-65.        , -65.01687961, -65.03321579, ..., -85.57731766,
#         -85.58269983, -85.58807029]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[76]': array([-65.        , -65.01692754, -65.033586  , ..., -85.5495648 ,
#         -85.55500494, -85.56043287]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].axon[0]': array([-65.        , -62.70454891, -60.16853092, ..., -87.23092564,
#         -87.23307819, -87.23523302]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].axon[1]': array([-65.        , -63.92725983, -62.46136301, ..., -87.76365307,
#         -87.76496518, -87.76628181]),
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].myelin[0]': array([-65.        , -66.5513032 , -67.88478737, ..., -89.46442951,
#         -89.46495638, -89.46548554])}

# %%
subtree = [x.name() for x in cell.soma.subtree()][:10]

# %% [markdown]
# We will now plot the voltages recorded for different locations in the subtree. We want to show the distances from the soma of the recording locations along with the section name.
# We will also plot voltage recordings from the soma and the axon initial segment.
#
# To calculate the distance of each section from the soma, we use the `distance` method from NEURON. The `select_dendritic_recordings` and `distances_to_soma` methods will be used to select the dendritic recordings and calculate the distances to the soma.

# %%
import neuron
from itertools import islice

def select_dendritic_recordings(all_recordings):
        """Select dendritic recordings from all recordings."""
        res = {}
        for key, value in all_recordings.items():
            if "myelin" in key:
                continue
            else:
                res[key] = value
        return res

def distances_to_soma():
    """Return the distance to the soma for each section."""
    res = {}
    all_recordings = cell.get_allsections_voltagerecordings()
    dendritic_recordings = select_dendritic_recordings(all_recordings)
    soma = cell.soma
    for key in dendritic_recordings.keys():
        section_name = key.rsplit(".")[-1].split("[")[0]  # e.g. "dend"
        section_idx = int(key.rsplit(".")[-1].split("[")[1].split("]")[0])  # e.g. 0
        attribute_value = getattr(cell.cell.getCell(), section_name)
        section = next(islice(attribute_value, section_idx, None))
        # section e.g. cADpyr_L2TPC_bluecellulab_x[0].dend[0]
        res[key] = neuron.h.distance(soma(0.5),section(0.5))
    return res

# %% [markdown]
# We now calculate the distances of the sections to the soma and plot the voltages recorded from the soma and the axon initial segment.

# %%
distances = distances_to_soma()
distances = {k: float(v) for k, v in distances.items()} # convert to float
distances = dict(sorted(distances.items(), key=lambda x: x[1])) # sort by distance

# %% [markdown]
# You can see the sorted distances of the sections to the soma below.

# %%
distances
# Out:
# {'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].soma[0]': 0.0,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[0]': 4.132154495613162,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[0]': 4.765188446744128,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[1]': 14.31071445662771,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[56]': 18.379717313542777,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[7]': 18.72565188608846,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].axon[0]': 19.58382446681999,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[2]': 21.36621485709223,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[1]': 22.94928443789968,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[4]': 28.591305994698544,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[58]': 32.48306590224313,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[9]': 35.667618263231226,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[3]': 35.669389444568615,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[33]': 36.996716900747586,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[11]': 45.176057024384555,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[10]': 49.42517496857583,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].axon[1]': 49.58382446681999,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[12]': 50.48827399214656,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[2]': 50.87825971384081,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[3]': 50.87825976187439,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[8]': 51.271298393796826,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[13]': 51.94445272486609,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[59]': 54.04714058470337,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[6]': 55.540303052041935,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[5]': 55.540305007384525,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[74]': 64.24869681239623,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[34]': 68.14638288352256,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[41]': 68.1463847439706,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[17]': 72.32763697482358,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[57]': 74.127322831481,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[10]': 83.38964576111702,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[60]': 93.87530030243069,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[4]': 96.48755269431791,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[73]': 100.91244622167407,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[49]': 104.56738755398104,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[14]': 115.69091757824029,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[5]': 118.80448505001037,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[75]': 120.55932216820668,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[11]': 128.1849816736902,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[18]': 129.09827686720868,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[21]': 129.70443239186386,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[35]': 131.05539235941643,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[42]': 131.05539290678556,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[18]': 131.49597496512618,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[61]': 138.65220567371856,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[76]': 140.4253262674191,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[38]': 140.9883765736489,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[66]': 155.3762498517425,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[51]': 160.85439903655225,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[62]': 163.35909185885941,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[63]': 167.55586001212822,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[64]': 176.83381652748454,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[65]': 177.28905382870164,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[20]': 177.6367370238564,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[16]': 184.22346702641576,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[12]': 187.7829910390483,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[19]': 188.56691047813882,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[15]': 189.43046150177435,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[24]': 194.40497832503735,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[19]': 194.40497903674185,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[23]': 200.1518994137304,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[50]': 200.58639647917846,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[53]': 203.89740912109608,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[13]': 204.337994632125,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[17]': 204.338001241116,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[68]': 205.05573687710864,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].dend[22]': 207.31989211502642,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[37]': 210.51938200182275,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[28]': 210.95997465947454,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[25]': 210.95997928408332,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[21]': 210.9599860997319,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[46]': 217.14138943285212,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[43]': 217.14138949526074,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[16]': 224.20397922118696,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[14]': 224.20399765973622,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[15]': 224.2040012334495,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[7]': 225.02715903706326,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[39]': 230.38535799054807,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[52]': 230.38540159510495,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[55]': 230.38540311446172,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[54]': 230.3854198507865,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[36]': 233.69639775538496,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[40]': 237.0073678575123,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[20]': 237.44798440332858,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[67]': 237.71057185209986,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[69]': 238.49243715184906,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[29]': 240.7589761131518,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[23]': 240.7589868431039,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[26]': 240.75898751465706,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[22]': 240.75899152627198,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[27]': 240.7589993689498,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[70]': 242.5732752622551,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[30]': 247.3809739706042,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[6]': 250.35918452963003,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[45]': 260.1843840825309,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[44]': 263.4953791597165,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[48]': 263.49537944873003,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[47]': 263.49538192269904,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[9]': 273.8306957945262,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[72]': 274.9278696890993,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[8]': 274.9754184084895,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[31]': 287.1129671133686,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[32]': 287.11297269192727,
#  'cADpyr_L2TPC_bluecellulab_c9e340c07dac466095dbb10fba2eb94d[0].apic[71]': 297.779499133758}

# %%
# Define colormap
color_map = get_cmap('viridis', len(subtree))
fig,ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 6))

title_fontsize = 16
label_fontsize = 16
tick_fontsize = 14
legend_fontsize = 11

recordings_subtree = {key: recordings[key] for key in subtree}
i=0

# Plot the voltage recordings from the subtree
for key in distances:
        if key in subtree:
                voltage = recordings[key]
                ax[0].plot(time, voltage, label=f'{key.split(".")[-1]} at {round(distances[key], 1)} $\mu$m', linewidth=0.75, color=color_map(i))
                i+=1

ax[0].legend(loc="upper center", bbox_to_anchor=(0.6, 1.0),fontsize=legend_fontsize)
ax[0].set_title("Apical dendrite voltage recordings", fontsize=title_fontsize)
ax[0].set_xlim(0, 15)
ax[0].set_ylim(-100, 60)
ax[0].set_xlabel("Time (ms)", fontsize=label_fontsize)
ax[0].set_ylabel("Voltage (mV)", fontsize=label_fontsize)
ax[0].tick_params(axis='both', which='major', labelsize=tick_fontsize)
ax[0].tick_params(axis='both', which='minor', labelsize=tick_fontsize)


# Plot soma and axon voltage recordings
color_map = get_cmap('tab10', len(subtree))
i=0
for key in distances.keys():
    if "axon" in key or "soma" in key:
        label = f'{key.split(".")[-1]} at {round(distances[key], 1)} $\mu$m'
        ax[1].plot(time, recordings[key], label=label, color=color_map(i))
        i+=1

ax[1].legend(fontsize=legend_fontsize)
ax[1].set_title("Soma and Axon voltage recordings",fontsize=title_fontsize)
ax[1].set_xlim(0, 15)
ax[1].set_ylim(-100, 60)
ax[1].set_xlabel("Time (ms)",fontsize=label_fontsize)
ax[1].set_ylabel("Voltage (mV)",fontsize=label_fontsize)
ax[1].tick_params(axis='both', which='major', labelsize=tick_fontsize)
ax[1].tick_params(axis='both', which='minor', labelsize=tick_fontsize)

plt.tight_layout()
plt.show()
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\m'
# <>:35: SyntaxWarning: invalid escape sequence '\m'
# <>:17: SyntaxWarning: invalid escape sequence '\m'
# <>:35: SyntaxWarning: invalid escape sequence '\m'
# /var/folders/ph/d20qkykn2f1_s_n6kkbc60h80000gn/T/ipykernel_23732/955995107.py:17: SyntaxWarning: invalid escape sequence '\m'
#   ax[0].plot(time, voltage, label=f'{key.split(".")[-1]} at {round(distances[key], 1)} $\mu$m', linewidth=0.75, color=color_map(i))
# /var/folders/ph/d20qkykn2f1_s_n6kkbc60h80000gn/T/ipykernel_23732/955995107.py:35: SyntaxWarning: invalid escape sequence '\m'
#   label = f'{key.split(".")[-1]} at {round(distances[key], 1)} $\mu$m'

# %% [markdown]
# Figure description:
#
# Left: The voltages in the soma and different sections along the apical dendrite. With increasing distance from the soma, the membrane potential decreases in amplitude.
#
# Right: The voltages in the soma and the AIS sections: axon[0] and axon[1]. The spike initiation (see between 0-2 ms) occurs in axon[0] section slightly before than that in the soma.

# %% [markdown]
# ### Exploring mechanism-scoped variables
#
# In this section we inspect variables exposed **inside each membrane mechanism** (e.g. NaTg, K_Pst, SKv3_1).
# These are mechanism-qualified names such as `NaTg.m`, `NaTg.ina`, `K_Pst.ik`, `pas.i`, etc.
#
# We use `bluecellulab.cell.section_tools.mechs_vars(section)` to query all mechanisms present at a given section (here the soma).
# Each mechanism lists its own parameters, states, and currents.
#
# Note: Top-level ionic currents (`ina`, `ik`, `ica`) belong directly to the segment itself, not to a specific mechanism.
# To list those, use **`bluecellulab.cell.section_tools.currents_vars`** instead.

# %%
from bluecellulab.cell import section_tools

section_tools.mechs_vars(cell.soma)
# Out:
# {'mech': {'pas': ['e', 'g', 'i'],
#   'CaDynamics_DC0': ['decay', 'gamma'],
#   'Ca_HVA2': ['gCa_HVAbar', 'h', 'ica', 'm'],
#   'Ca_LVAst': ['gCa_LVAst', 'gCa_LVAstbar', 'h', 'ica', 'm'],
#   'Ih': ['gIh', 'gIhbar', 'ihcn', 'm'],
#   'K_Pst': ['gK_Pst', 'gK_Pstbar', 'h', 'ik', 'm'],
#   'K_Tst': ['gK_Tst', 'gK_Tstbar', 'h', 'ik', 'm'],
#   'NaTg': ['gNaTg',
#    'gNaTgbar',
#    'h',
#    'ina',
#    'm',
#    'slopeh',
#    'slopem',
#    'vshifth',
#    'vshiftm'],
#   'SK_E2': ['gSK_E2', 'gSK_E2bar', 'ik', 'z', 'zTau'],
#   'SKv3_1': ['gSKv3_1', 'gSKv3_1bar', 'ik', 'm']}}

# %% [markdown]
# From the listing above, we see that the NaTg sodium channel mechanism exposes several variables, including ina, which represents the sodium current flowing through this mechanism.

# %% [markdown]
# Let’s select the sodium current variable exposed by the NaTg mechanism.
# By recording NaTg.ina at the midpoint of the soma, we capture the inward sodium current that underlies the depolarizing phase of the action potential.

# %%
section_obj = cell.get_section("soma[0]")
# Add the recording
cell.add_variable_recording("NaTg.ina", section_obj, 0.5)  # total sodium current

# %%
sim.run(250, cvode=False)
time = cell.get_time()
soma_voltage = cell.get_soma_voltage()

# %% [markdown]
# We get the NaTg.ina mechanism-scoped sodium that we just recorded

# %%
ina_density = cell.get_variable_recording(
    variable="NaTg.ina",   # sodium current from the NaTg mechanism
    section=section_obj,    # e.g. soma[0] (already chosen earlier)
    segx=0.5                # position along the section (center)
)
t = cell.get_time()         # time vector (ms)

# %% [markdown]
# Important, In NEURON, the default unit of ionic distributed mechanism currents is **mA/cm²**, i.e. a current density (current per unit area) [unit reference](https://www.neuron.yale.edu/neuron/static/docs/units/unitchart.html).
# To convert this to total current of the soma, we multiply by the soma surface area and a unit conversion factor 0.01 [forum explanation](https://www.neuron.yale.edu/phpBB/viewtopic.php?p=17732#p17732).

# %%
soma_area_um2 = neuron.h.area(0.5, sec=section_obj)
ina_nA = ina_density * soma_area_um2 * 0.01

# %%
plt.figure(figsize=(8, 4))
plt.plot(t, ina_nA, color="blue", label="NaTg.ina (nA)")
plt.xlabel("Time (ms)")
plt.ylabel("Current (nA)")
plt.title(f"Total Na+ current at {section_obj.name()} (x=0.5)")
plt.grid(True)
plt.legend()
plt.show()
